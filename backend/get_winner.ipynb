# %%
import pandas as pd

emails = pd.read_csv('emails.csv')

# drop first column
emails = emails.drop(emails.columns[0], axis=1)
emails = emails.dropna()
# deleate all rows with alejandrososawelford@gmail.com
emails = emails[emails['gola'] != 'alejandrososawelford@gmail.com']

# save to csv
emails
# Out:
#                              gola
# 2               gracias@crack.com
# 3        nicolaspelella@gmail.com
# 4          sandywelford@gmail.com
# 5    sosawelfordpedro18@gmail.com
# 6      francoferrante95@gmail.com
# 7            maite.atin@gmail.com
# 8            pablo.ar02@gmail.com
# 9            joacoponfe@gmail.com
# 11            tatokogan@gmail.com
# 13         robinwho.geo@yahoo.com
# 14          vida.ailen7@gmail.com
# 15   daviddelafuente545@gmail.com
# 16             fperczyk@gmail.com
# 17              marzikg@gmail.com
# 18          Lucas_rhm@hotmail.com
# 19          franluntref@gmail.com
# 25          rmolinari00@gmail.com
# 26          joanthourte@gmail.com
# 27         jsosawelford@gmail.com
# 29        burgolemanuel@gmail.com
# 31         kaspierowicz@gmail.com
# 32       marcovitali009@gmail.com
# 33           fedefigini@gmail.com
# 34      guido.corleto@hotmail.com
# 36            tomyjara1@gmail.com
# 38      perez.gonzalo.n@gmail.com
# ...
